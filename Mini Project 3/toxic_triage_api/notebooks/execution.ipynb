# %% [markdown]
# I used Google Colab so I am mounting the drive to colab:

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# /tmp/ipykernel_2267/1408506528.py in <cell line: 0>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      95 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      96   """Mount your Google Drive at the specified mountpoint path."""
# ---> 97   return _mount(
#      98       mountpoint,
#      99       force_remount=force_remount,
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     132   )
#     133   if ephemeral:
# --> 134     _message.blocking_request(
#     135         'request_auth',
#     136         request={'authType': 'dfs_ephemeral'},
#
# ...

# %% [markdown]
# **NOTE**: I used only 1000 records for training and testing. For Better results use more records.

# %% [markdown]
# Going to the project directory and executing training

# %%
# Change directory to your project root
# %cd /content/drive/MyDrive/toxic_triage_api

# Install the latest transformers (let pip handle the wheel resolution)
# !pip install transformers

# Execute the training script
# !python src/train.py
# Out:
# /content/drive/MyDrive/toxic_triage_api
# ...
# /content/drive/MyDrive/toxic_triage_api/src/train.py:11: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler=GradScaler()
# ...
# Loading weights: 100% 100/100 [00:00<00:00, 2418.78it/s, Materializing param=transformer.layer.5.sa_layer_norm.weight]
# DistilBertModel LOAD REPORT from: distilbert-base-uncased
# Key                     | Status     |  |
# ------------------------+------------+--+-
# vocab_projector.bias    | UNEXPECTED |  |
# vocab_transform.bias    | UNEXPECTED |  |
# vocab_transform.weight  | UNEXPECTED |  |
# vocab_layer_norm.weight | UNEXPECTED |  |
# vocab_layer_norm.bias   | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# ...

# %% [markdown]
# Executing testing

# %%
# %cd /content/drive/MyDrive/toxic_triage_api

# !python src/evaluate.py
# Out:
# /content/drive/MyDrive/toxic_triage_api
# ...
# Loading weights: 100% 100/100 [00:00<00:00, 1236.61it/s, Materializing param=transformer.layer.5.sa_layer_norm.weight]
# DistilBertModel LOAD REPORT from: distilbert-base-uncased
# Key                     | Status     |  |
# ------------------------+------------+--+-
# vocab_transform.weight  | UNEXPECTED |  |
# vocab_transform.bias    | UNEXPECTED |  |
# vocab_layer_norm.weight | UNEXPECTED |  |
# vocab_projector.bias    | UNEXPECTED |  |
# vocab_layer_norm.bias   | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Evaluating: 100% 63/63 [00:06<00:00,  9.07it/s]
# ROC AUC Score: 0.9352
# F1 Score: 0.2351

# %% [markdown]
# This is the API section, run this to go to the interface and test

# %%
# Change to the app directory
# %cd /content/drive/MyDrive/toxic_triage_api

# Install required deployment tools
# !pip install fastapi uvicorn pydantic

# Install localtunnel to expose the port
# !npm install -g localtunnel

# Start the FastAPI server in the background using nohup
# !nohup uvicorn app.api:app --host 0.0.0.0 --port 8000 > server.log 2>&1 &

# Start the tunnel to expose port 8000 to the public internet
# !npx localtunnel --port 8000
# Out:
# /content/drive/MyDrive/toxic_triage_api
# ...
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸
# added 22 packages in 3s
# ⠸
# ⠸3 packages are looking for funding
# ⠸  run `npm fund` for details
# ⠸⠙⠹⠸⠼⠴⠦⠧⠇your url is: https://true-suits-happen.loca.lt
# ^C
